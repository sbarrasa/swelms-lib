// %%
import com.swelms.domain.person.*
import com.bank.locale.*
import com.swelms.common.locale.*

Locale.registerConfigs(LocaleConfig_en, LocaleConfig_es)
Locale.lang = "es"
println(Gender.M.description)
// Out:
// Masculino
